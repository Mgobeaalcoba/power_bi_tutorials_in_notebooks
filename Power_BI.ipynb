# %% [markdown]
# <a href="https://colab.research.google.com/github/Mgobeaalcoba/TutorialesEnJupyters/blob/main/Power_BI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Business Intelligence**: Es la habilidad de transformar los **datos en información**, y a su vez esta **información en conocimiento**, para agilizar el tiempo en cuanto a la toma de decisiones.
#
# **Flujo de BI**
#
# ● **ETL**: Extracción de datos, consolidación de fuentes, limpieza y transformación.
#
# ● **Modelado**: Relaciones, indicadores, optimización.
#
# ● **Reporting**: Visualización de datos, reportes, dashboards, storytelling.
#
# **Power BI**: Es una solución integral de Business Intelligence, que proporciona una vista detallada de los datos más críticos dentro de una organización.
#
# Suite de Negocio
#
# ● **Power BI Desktop**: Herramienta de escritorio orientada al ambiente de desarrollo, que permite conectarte a diversas fuentes de datos y crear reportes.
#
# ● **Power BI Service Service**: En la nube que permite establecer todo el ambiente colaborativo.
#
# ● **Power BI Mobile**: Aplicación para celular que permite visualizar e interactuar, con un informe desde cualquier dispositivo.
#
# Componentes de Power BI:
#
# ● **Power Query ETL** : Extracción, transformación y carga de los datos.
#
# ● **Power Pivot(DAX) Modelamiento**: Responder todas las preguntas de negocio.

# %% [markdown]
# Tipos de conexiones:
#
# Power BI permite conectarnos a una gran variedad de fuentes de datos, desde archivos Excel, bases de datos en SQL Server, hasta sitios en la web.
#
# Tipos de conexión:
# ● Importación: Los datos se copian a manera local dentro del modelo de Power BI (es el tipo más común).
#
# ● Direct Query: Los datos no se copian, pues cada interacción solicita una consulta a la base de datos.
#
# ● Live Connection o Dinámica: Lectura desde SSAS o desde un conjunto de datos de Power BI Service.
#
# ● Modelos Compuestos: Combina las tecnologías de importación y Direct Query. También permite utilizar múltiples conjuntos de datos.

# %% [markdown]
# Buenas practicas de BI: Conectarse siempre a tablas y no a hojas de calculo. Porque las hojas de calculo pueden tener datos sucios.

# %% [markdown]
# Power Query = ETL con Power BI
#
# Power Query
# Es una tecnología de conexión de datos que permite detectar, conectar, combinar y refinar distintos orígenes de datos para satisfacer las necesidades de análisis.
#
# ¡Qué hace Power Query?
#
# ● Extrae: Desde prácticamente cualquier fuente de datos.
#
# ● Transforma: Desde fusionar, combinar, limpiar o enriquecer la data.
#
# ● Carga: Los datos para su posterior análisis en Power BI.
#
# Puntos a considerar:
#
# ● El objetivo del Power Query es obtener datos de una variedad de fuentes, y prepararlos para su posterior análisis.
#
# ● El objetivo de esta herramienta no es analizar los datos.
#
# ● Magia: Colección de pasos que se realiza para llegar a un resultado, además permite retroceder o avanzar sin modificar el origen de datos. Similar al proceso que realiza un macro en Excel.

# %% [markdown]
# Desde "Transformar datos" en Power BI se accede a Power Query

# %% [markdown]
# Power Query re categoriza el tipo de dato de forma automatica al cargar un file. Por lo que hay que validar que tipo de dato va acompañado a cada columna que hemos cargado.

# %% [markdown]
# Es importante destacar que las fechas en el proceso de ETL siempre se deben trabajar como filas y no como columnas. Si las tenemos como filas, entonces debemos seleccionar la primera columna de nuestra tabla. Ej "producto" y con el boton derecho del mouse vamos a elegir la opción de "Anulación de dinamización de otras columnas".

# %% [markdown]
# **Combinaciones** de fuentes de datos en Power BI
#
# **Anexar**:
# • Permite unir dos o mas tablas.
#
# • Se recomienda que ambos tengan la misma estructura, si este no es el caso, el sistema añade al conjunto final los campos de todas demás con valores nulos.
# • Es similar a una operación de UNION del standar sql.
#
# • Los resultados pueden ser una nueva consulta o ser agregada a un paso de la existente.
#
# **Combinar**
#
# • La funcionalidad de combinar consultas. Nos permite tomar dos tablas y cruzarlsas mediante una columna en común.
#
# • Usualmente es utilizado para complementar información de una tabla.
#
# • Es el equivalente más cercano a la función JOIN del standar SQL.
#
# **Anexar binarios:**
#
# • Esta funcionalidad, nos permite extraer las tablas de los archivos mediante un proceso automatizado.
#
# • Usualmente es utilizado mediante el conector de carpeta.
#
# • Es de especialidad utilidad cuando la fuente de información se encuentra demasiado fragmentada como para la operación de anexar.

# %% [markdown]
# Tiene que tener o una tabla o una hoja que tengan el mismo nombre para realizar la anexión automatica dentro de una misma carpeta.

# %% [markdown]
# El Flujo de BI consiste en:
#
# ETL
# Modelado de Datos
# Visualización de Datos
# ETL se maneja con Power Query, mientras que el Modelado de Datos, se realiza con Power Pivot.
#
# El Modelado de Datos en Power BI se centra en realizar análisis complejos entre varias tablas conectadas por un campo en común.
#
# Modelado de datos es crear relaciones entre tablas.

# %% [markdown]
# Sin un correcto modelado de datos y cruzando categorias de dos fuentes distintas la información no va a ser consistente. Por lo que es fundamental un correcto modelado luego del ETL pero antes de comenzar a trabajar con los dashboards.

# %% [markdown]
# ![Modelado de datos en Power Bi.PNG](data:image/png;base64,...)

# %% [markdown]
# Con respecto al tema de modelado, existen dos arquitecturas que son usadas en el mundo de BI para asegurar que existe un consumo estructurado de información. Estas son arquitectura en estrella y arquitectura en copo de nieve.
# La nomenclatura que usa Renzo se refiere al tipo de tablas que se usan en el modelo, dimensiones (DIM) y hechos (FACT), mismas que forman parte teórica de las arquitecturas mencionadas previamente.
# En el contexto del ejercicio, tenemos una arquitectura de estrella principal, pero la tabla de presupuestos puede indicar tambien que se da comportamiento en esa parte para arquitectura de copo de nieve.

# %% [markdown]
# Relaciones de Tablas
#
# Llaves primarias (Primary Keys): Se utilizan para definir la clave principal de la tabla. No puede contener valores nulos ni duplicados.
# Llaves foráneas (Foreign Keys): Es una columna o conjunto de columnas, que contiene el valor que hace referencia a una fila de otra tabla.
# Tipos de Relaciones
#
# 1 a 1 (1-1): Ambas tablas se conectan con sus llaves primarias.
# 1 a varios(1-*): Ocurre cuando se conecta una llave primaria con una llave foránea de otra tabla. Es la que se debe buscar en Power BI.
# Varios a varios(* - *): Ocurre cuando ambas tablas se relacionan por sus llaves foráneas (ninguna de las columnas tiene valores únicos). Se recomienda evitar a menos que sea necesario.

# %% [markdown]
# Lenguaje DAX
# Es un lenguaje de expresiones en donde utiliza formulas analíticas y funciones operativas que permiten el calculo de uno o mas valores , creado para manipular un modelo de datos tabular y se baso de Excel ; he de ahí su semejanza en cuanto a la estructura de formulación .
# Podemos encontrar este lenguaje en powerBI , SAS Tabular y Excel en el complemento de powerquery
#
# ¿Porque DAX?
#
# Relaciones de Navegación
# Calculo de Dimensiones
# Manejo de Dimensiones de Tiempo (Time Intelligence)
# ¿que podemos Crear ?
#
# Columnas Calculadas: permite métodos para conectar tablas con múltiples columnas clave y crea columnas nuevas en el modelos de datos
# Tablas Calculadas: crea una tabla derivada de otra tabla .
# Medidas: Soporta la inteligencia de tiempo y crea cálculos dinámicos , que es lo mas usado en powerBi
# Convenciones del Lenguaje (Formato General )
#
# ‘Nombre de tabla’ : [nombre de columna]
# Ejemplo : ‘tabla productos’ : [Precio]
#
# El nombre de la tabla puede ser omitido al utlizarse en columnas calculadas mas no se recomienda hacerlo

# %% [markdown]
# = calendarauto() --> genera un tabla con todas las fechas desde el mínimo hasta el máximo del dataset. Esto sirve como dimensión para poder relacionar más Fact tables por ejemplo.

# %% [markdown]
# Buena practica = Cuando vayamos a realizar nuevas medidas debemos guardarlas en una nueva tabla que elaboramos desde "Especificar datos" a la que podemos denominar como "Tabla - Medidas". Allí iremos agregando las medidas que queramos.

# %% [markdown]
# Las medidas calculadas no ocupan espacio en memoria. Las columnas calculadas y las tablas calculadas si lo ocupan.
#
# Todas estas se pueden armar con DAX - Lenguaje de Power BI

# %% [markdown]
# Uso del **Calculate** - DAX
#
# Formula de Agregación y la mas usada en powerBi , Aunque solo tiene dos parámetros nos permite realizar una acción llamada "Modificador de contexto de filtro " y crea un contexto de fila dentro de nuestros cálculos
#
# Sintaxis o Codigo
#
# = CALCULATE(expression, filter1 || filter2)

# %% [markdown]
# Time Intellegence o Inteligencia de Tiempo:
#
# ¿Qué es inteligencia de tiempo?
# Hace referencia a las técnicas , herramientas y metodologías que nos permite analizar nuestras medidas minuciosamente a través del concepto de “tiempo” , es decir que esta presente en todas las soluciones de inteligencia de negocios como punto de partida para explorar la información :
#
# Desde analizar evolución de nuestras medidas en tiempo , se utiliza una nueva dimensión (tablas) Fechas y calendario de manera continua sin que falle ni un solo dia entre las fechas , este funciona en nuestro modelo .
# monitorear el crecimiento o descreimiento de manera detallada .
# Realizar proyecciones .

# %% [markdown]
# Hay un script en lenguaje M que pego debajo y que nos permite crear una tabla de tiempo para manejar nuestra database con el recorte temporal que queramos.
# Lo pego debajo

# %% [markdown]
# let fnDateTable = (StartDate as date, EndDate as date, FYStartMonth as number) as table =>
#  let
#  DayCount = Duration.Days(Duration.From(EndDate - StartDate)),
#  Source = List.Dates(StartDate,DayCount,#duration(1,0,0,0)),
#  TableFromList = Table.FromList(Source, Splitter.SplitByNothing()),
#  ChangedType = Table.TransformColumnTypes(TableFromList,{{"Column1", type date}}),
#  RenamedColumns = Table.RenameColumns(ChangedType,{{"Column1", "Date"}}),
#  InsertYear = Table.AddColumn(RenamedColumns, "Year", each Date.Year([Date]),type text),
#  InsertYearNumber = Table.AddColumn(RenamedColumns, "YearNumber", each Date.Year([Date])),
#  InsertQuarter = Table.AddColumn(InsertYear, "QuarterOfYear", each Date.QuarterOfYear([Date])),
#  InsertMonth = Table.AddColumn(InsertQuarter, "MonthOfYear", each Date.Month([Date]), type
# text),
#  InsertDay = Table.AddColumn(InsertMonth, "DayOfMonth", each Date.Day([Date])),
#  InsertDayInt = Table.AddColumn(InsertDay, "DateInt", each [Year] * 10000 + [MonthOfYear] * 100
# + [DayOfMonth]),
#  InsertMonthName = Table.AddColumn(InsertDayInt, "MonthName", each Date.ToText([Date],
# "MMMM"), type text),
#  InsertCalendarMonth = Table.AddColumn(InsertMonthName, "MonthInCalendar", each
# (try(Text.Range([MonthName],0,3)) otherwise [MonthName]) & " " & Number.ToText([Year])),
#  InsertCalendarQtr = Table.AddColumn(InsertCalendarMonth, "QuarterInCalendar", each "Q" &
# Number.ToText([QuarterOfYear]) & " " & Number.ToText([Year])),
#  InsertDayWeek = Table.AddColumn(InsertCalendarQtr, "DayInWeek", each
# Date.DayOfWeek([Date])),
#  InsertDayName = Table.AddColumn(InsertDayWeek, "DayOfWeekName", each Date.ToText([Date],
# "dddd"), type text),
#  InsertWeekEnding = Table.AddColumn(InsertDayName, "WeekEnding", each
# Date.EndOfWeek([Date]), type date),
#  InsertWeekNumber= Table.AddColumn(InsertWeekEnding, "Week Number", each
# Date.WeekOfYear([Date])),
#  InsertMonthnYear = Table.AddColumn(InsertWeekNumber,"MonthnYear", each [Year] * 10000 +
# [MonthOfYear] * 100),
#  InsertQuarternYear = Table.AddColumn(InsertMonthnYear,"QuarternYear", each [Year] * 10000 +
# [QuarterOfYear] * 100),
#  ChangedType1 = Table.TransformColumnTypes(InsertQuarternYear,{{"QuarternYear",
# Int64.Type},{"Week Number", Int64.Type},{"Year", type text},{"MonthnYear", Int64.Type}, {"DateInt",
# Int64.Type}, {"DayOfMonth", Int64.Type}, {"MonthOfYear", Int64.Type}, {"QuarterOfYear",
# Int64.Type}, {"MonthInCalendar", type text}, {"QuarterInCalendar", type text}, {"DayInWeek",
# Int64.Type}}),
#  InsertShortYear = Table.AddColumn(ChangedType1, "ShortYear", each Text.End(Text.From([Year]),
# 2), type text),
#  AddFY = Table.AddColumn(InsertShortYear, "FY", each "FY"&(if [MonthOfYear]>=FYStartMonth
# then Text.From(Number.From([ShortYear])+1) else [ShortYear]))
# in
#  AddFY
# in
#  fnDateTable

# %% [markdown]
# ![Tabla Calendario en Lenguaje M.PNG](data:image/png;base64,...)

# %% [markdown]
# **Funciones iterativas o iteradores X**
#
# Este tipo de funciones son especiales dentro de DAX, pues nos permiten crear operaciones a nivel de fila y calcular el resultado.
# Las funciones iterativas también se les conoce como funciones X
# Algunas de estas funciones son: SUMX, AVERAGEX, MAXX, MINX, STDEVX.S, PERCENTILEX.EXC y CONCATENATEX

# %% [markdown]
# **Data Storytelling**
#
# Nos permite hacer que los usuarios se desenvuelvan de una manera más dinámica con nuestros reportes.
#
# Ayuda a que captemos la atención del usuario y él mismo descubra nueva información a través de las interacciones.

# %% [markdown]
# Elegir la correcta **visualización** es una de las partes más importantes de nuestro proyecto: Comunicar nuestras ideas o descubrimientos a un público más amplio y de forma dinámica.
#
# ● Menos es más.
# ● Los colores son importantes, úsalos bien.
# ● Mantén tus elementos bien alineados.
# ● Se constante.
# ● No siempre es bueno mostrar toda una cifra.
# ● Muestra solo información relacionada.
# ● Una mala elección de un visual puede ocasionar que la información no se transmita de manera correcta.

# %% [markdown]
# Los graficos circulares solo deben usarse para 2 o 3 categorias como maximo.

# %% [markdown]
# ¿Que es un informe ?
# Es la coleccion de paginas segmentadas por un tema particular y ofrece una vista resumida e interactiva con la capacidad de filtrado de acuerdo con las necesidades del usuario .
#
# Data Storytelling con power BI
#
# Marcadores : Guardan la configuracion de la vista actual del informe.
# Botones: Permite activar una accion de nuestro informe.
# Tooltips Avanzados : Permite mostrar detalle adicional a nuestras visualizaciones

# %% [markdown]
# Paso a paso para hacer un informe en Power BI y en Business Intelligence en general:
#
# 1- Obtención de los datos a trabajar
#
# 2- ETL de los datos a trabajar. En el caso de Power Bi podemos hacerlo con Power Query
#
# 3- Modelado de los datos y sus relaciones entre las distintas tablas. Se hace desde la pestaña de modelado con la que cuenta Power Bi
#
# 4- Creación de una tabla vacia para armar allí las medidas explicitas con las que vamos a trabajar. Siempre es mejor trabajar con medidas explicitas que con medidas implicitas. Luego eliminar la unica columna de esta tabla para que la misma quede como una "tabla de medidas" - Buena practica en BI
#
# 5- Estamos en condiciones de comenzar a graficar y a elaborar nuestro informe.

# %% [markdown]
# Para crear un **tooltip basico** se arrastra una categoria que queremos agregar y ver al pasar el cursor a la sección "información sobre la herramienta"

# %% [markdown]
# **Tooltip avanzado:**
# 1- Abro nueva pagina
#
# 2- En información de la pagina activo la opción "Información sobre la herramienta"
#
# 3- En tamaño de la pagina selecciono "Información sobre herramientas"
#
# 4- Hago mis graficas luego oculto la pagina con click derecho sobre la solapa.
#
# 5- Me posiciono sobre la grafica en la que quiero hacer el tooltip. Voy a formato. Luego Información sobre herramienta y alli selecciono tipo "pagina del informe" y pagina el nombre de la solapa que guarda el tooltip

# %% [markdown]
# El objetivo de un informe siempre es IMPACTAR

# %% [markdown]
# Al lado del menu de formato Power Bi nos ofrece un menu de análitica de datos. Donde podremos incorporar a los gráficos info tal como linea de tendencia, linea de minimo, de maximo, de promedio, de mediana, percentiles y demas medidas de tendencia central y dispersión.

# %% [markdown]
# Allí por ejemplo podremos poner una linea de promedio para cada una de las dimensiones que estamos analizando. Por ej, cantidad de ventas y total de ventas.

# %% [markdown]
# Una herramienta maravillosa con la que cuenta Power Bi, al menos en sus mapas de dispersión, aunque de seguro se puede replicar en otras graficas, es la posibilidad de incorporar una medida de tiempo en "eje de reproducción". Ello le agrega un elemento dinamico a la presentación como se puede observar en el gran video de storytelling:

# %% [markdown]
# Si usamos graficas con eje continuo podemos entonces hacer forecast y previsiones de comportamiento directamente de la sección de análitica de datos de Power Bi.

# %% [markdown]
# En Power BI también podemos ingresar scripts de Python / R para visualización de datos en PowerBI, si ya vienen trabajando lo fundamental en estos lenguajes lo pueden hacer sin ningún problema.
#
# Es interesante ya que en estos lenguajes aprendemos a hacer visualizaciones propias que pueden complementar mucho más nuestros reportes.

# %% [markdown]
# Al subir un reporte a Power BI Service nos sube la reportería pero tambien nuestro conjunto de datos usados.
# Limmitantes de BI Service: No podemos editar formulas, no podemos acceder a power query y menos podemos ver ni corregir el modelamiento de los datos. Esta hecho sobre todo para poder compartir la reportería y generar un ambiente colaborativo.
#
# Áreas de Trabajo en Power BI Service
#
# Son los lugares para colaborar con colegas, compañeros para crear colecciones de paneles, informes e informes paginados.
#
# En área de trabajo se define al conjunto de usuarios que tienen acceso a datos, informes y paneles específicos. Adicionalmente, es posible:
#
# Asignar roles específicos.
#
# Separar áreas de la organización.
#
# Creación de aplicaciones y aplicaciones de plantilla

# %% [markdown]
# En el ambiente colaborativo (Si o si con licencia PRO) dentro de una aera de trabajo podemos establecer cuatro tipos de permisos: admin, miembro, colaborador y visor.
# Es muy similar al tipo de permisos del ambiente colaborativo de gsuite

# %% [markdown]
# En dashboard voy a poder anclar graficos que provienen de dataset completamente distintos. Es similar a los dashboard en Looker.

# %% [markdown]
# En los dashboars podemos ingresar tmb videos de youtube o vime, fotos, y diversos otros tipos de archivos junto con nuestras graficas. Lo que le da mucha potencia.
#
# Los dashboars, que son distintos a los informes, se graban de forma automatica.

# %% [markdown]
# Puerta de Enlace o Gateway:
#
# Es un componente que facilita el acceso de datos de la red (controlador de acceso), que permite conceder a los usuarios su conexión siempre y cuando cumplan ciertos criterios.
#
# Tipos de puerta de enlace.
#
# Modo personal : permite a un usuario único a conectarse a las fuentes sin que estas se puedan compartir.
#
# Modo múltiple : permite a varios usuarios a que se conecten múltiples fuentes de datos locales.

# %% [markdown]
# El uso de las puertas de enlace nos permite automatizar la actualización de los reportes con sus respectivas fuentes de datos.
#
# Aqui, valido la fuente de datos y seleccione la cantidad de actualizaciones que yo quiero para mi reporte. Diaria, semanal, etc con un maximo de 8 veces al dái si tengo la licencia PRO
